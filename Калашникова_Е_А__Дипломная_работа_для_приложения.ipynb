# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import LeaveOneOut, cross_val_predict
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error, mean_absolute_percentage_error
import pickle

# %%
data1=pd.read_excel('X_bp.xlsx')

# %%
data2=pd.read_excel('X_nup.xlsx')

# %%
data = pd.merge(data1, data2, left_index=True, right_index=True, how='inner')

# %%
data=data.drop(['Unnamed: 0_y', 'Unnamed: 0_x'], axis=1) ### Удаление лишнего столбца

# %%
data_MU=data.drop(['Прочность при растяжении, МПа'], axis=1)
data_Pr=data.drop(['Модуль упругости при растяжении, ГПа'], axis=1)

# %%
data_22=data.head(23).copy()

# %%
data_22a=data.iloc[23:].copy()

# %%
data_22_MU=data_22.drop(['Прочность при растяжении, МПа'], axis=1)
data_22_Pr=data_22.drop(['Модуль упругости при растяжении, ГПа'], axis=1)

# %%
X_22_MU=data_22_MU.drop(['Модуль упругости при растяжении, ГПа'], axis=1)
y_22_MU=data_22_MU['Модуль упругости при растяжении, ГПа']

X_22_Pr=data_22_Pr.drop(['Прочность при растяжении, МПа'], axis=1)
y_22_Pr=data_22_Pr['Прочность при растяжении, МПа']

# %%
loo = LeaveOneOut()

# %%
model_rf_MU = RandomForestRegressor(n_estimators=50, max_depth=10, random_state=42)
y_22_MU_pred = cross_val_predict(model_rf, X_22_MU, y_22_MU, cv=loo)
MAE_MU = mean_absolute_error(y_22_MU, y_22_MU_pred)
MSE_MU = mean_squared_error(y_22_MU, y_22_MU_pred)
r2_MU = r2_score(y_22_MU, y_22_MU_pred)
RMSE_MU = root_mean_squared_error(y_22_MU, y_22_MU_pred)
MAPE_MU= mean_absolute_percentage_error(y_22_MU, y_22_MU_pred)
print(MAE_MU, MSE_MU, r2_MU, RMSE_MU, MAPE_MU)
# Out:
# 0.3321739130434894 0.2850937198067708 0.9701947474747467 0.5339416820278885 0.004410216836303946

# %%
model_rf_Pr = RandomForestRegressor(n_estimators=50, max_depth=10, random_state=42)
y_22_Pr_pred = cross_val_predict(model_rf, X_22_Pr, y_22_Pr, cv=loo)
MAE_Pr = mean_absolute_error(y_22_Pr, y_22_Pr_pred)
MSE_Pr = mean_squared_error(y_22_Pr, y_22_Pr_pred)
r2_Pr = r2_score(y_22_Pr, y_22_Pr_pred)
RMSE_Pr = root_mean_squared_error(y_22_Pr, y_22_Pr_pred)
MAPE_Pr= mean_absolute_percentage_error(y_22_Pr, y_22_Pr_pred)
print(MAE_Pr, MSE_Pr, r2_Pr, RMSE_Pr, MAPE_Pr)
# Out:
# 103.29468599033721 19172.820182501004 0.9187059857071342 138.46595315275522 0.049106671232843006

# %%
with open('model_rf_MU.pkl', 'wb') as f:
    pickle.dump(model_rf_MU, f)

# %%
with open('model_rf_Pr.pkl', 'wb') as f:
    pickle.dump(model_rf_Pr, f)
